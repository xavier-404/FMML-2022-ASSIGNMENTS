# %% [markdown]
# <a href="https://colab.research.google.com/github/xavier-404/FMML-2022-ASSIGNMENTS/blob/main/Copy_of_FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-23 09:49:58--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   314MB/s    in 0.2s
#
# 2023-05-23 09:49:59 (314 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 4372   1609.04802v5  Despite the breakthroughs in accuracy and spee...    cs
# 199    1707.03502v2  Sensor-based activity recognition seeks the pr...    cs
# 3346   1512.00486v2  In order to push the performance on realistic ...  stat
# 28348  1706.03038v2  Despite significant progress in the developmen...    cs
# 10655   1206.4682v1  The paper presents a new copula based method f...    cs
# ...             ...                                                ...   ...
# 31939   1301.3753v2  Several recent results in machine learning hav...    cs
# 29303  1709.00531v1  Registering a 3D facial model to a 2D image un...    cs
# 3765    1412.5896v3  In this work we study the properties of deep n...  stat
# 28229  1705.10413v1  Generative adversarial networks (GANs) has gai...    cs
# 21917  1502.06689v1  We consider the problem of noisy 1-bit matrix ...  stat
#
#                                                    title  year  \
# 4372   Photo-Realistic Single Image Super-Resolution ...  2016
# 199    Deep Learning for Sensor-based Activity Recogn...  2017
# 3346   Loss Functions for Top-k Error: Analysis and I...  2015
# 28348  Okutama-Action: An Aerial View Video Dataset f...  2017
# 10655            Copula-based Kernel Dependency Measures  2012
# ...                                                  ...   ...
# 31939  Switched linear encoding with rectified linear...  2013
# 29303  Facial 3D Model Registration Under Occlusions ...  2017
# 3765                   On the Stability of Deep Networks  2014
# 28229  Learning to Generate Chairs with Generative Ad...  2017
# 21917  1-Bit Matrix Completion under Exact Low-Rank C...  2015
#
#                                                 keywords
# 4372   [breakthroughs, resolution, convolutional, ups...
# 199    [recognition, knowledge, activities, multitude...
# 3346   [performance, realistic, benchmark, significan...
# 28348  [significant, development, detection, algorith...
# 10655  [measuring, dependence, variables, discrepancy...
# ...                                                  ...
# 31939  [established, connections, autoencoders, artif...
# 29303  [registering, occlusion, difficult, landmarks,...
# 3765   [properties, preserving, embedding, conclusion...
# 28229  [generative, adversarial, tremendous, populari...
# 21917  [completion, constraint, underlying, observing...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 4372     [breakthroughs, resolution, convolutional, ups...
# 199      [recognition, knowledge, activities, multitude...
# 3346     [performance, realistic, benchmark, significan...
# 28348    [significant, development, detection, algorith...
# 10655    [measuring, dependence, variables, discrepancy...
#                                ...
# 6190     [investigates, distributed, processing, recogn...
# 12582    [transform, sparsifying, transform, algorithms...
# 21761    [probabilistic, multinomial, classification, c...
# 11349    [algorithms, efficient, optimization, projecti...
# 32114    [framework, optimization, algorithms, literatu...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8872 words.
# Out of those 4535 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="016763ca-3777-43e8-a401-49d898436b2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("016763ca-3777-43e8-a401-49d898436b2f")) {                    Plotly.newPlot(                        "016763ca-3777-43e8-a401-49d898436b2f",                        [{"x":["estimates","minimizing","knowledge","inferring","realistic","reconstruction","motivated","extensive","resolution","convolutional","frequency","perceptually","principally","resulting","discriminator","perceptual","adversarial","unsatisfying","optimization","similarity","upscaling","breakthroughs","objective","benchmarks","significant","downsampled","framework","differentiate","generative","advancement","literature","activities","additionally","summarize","approaches","challenges","incremental","automatic","application","conventional","unsupervised","generalization","tremendous","performance","extraction","heuristic","recognition","promising","introduce","ambiguity","experiments","competitive","increased","functions","perspective","evaluation","established","improvements","practical","efficient","significantly","comparison","benchmark","typically","theoretical","interesting","comparing","modifications","simultaneously","multiclass","development","algorithms","applications","representative","challenging","sequences","annotated","including","detection","scenarios","transition","concurrent","dimensional","distributions","advantageous","selection","illustrate","distribution","important","consistent","embedding","properties","estimator","similarly","invariant","dependence","contributions","variables","discrepancy","statistics","independence","convergence","transformation","measuring","increasing","information","dependency","distractors","estimating","monocular","predicted","distraction","cluttered","estimation","automatically","photometric","demonstrate","independently","distractor","environments","supervised","egomotion","implementation","localized","outperforms","evaluations","predictions","explicitly","attribute","partially","especially","attributes","architecture","decisions","combining","determine","techniques","committee","behavioral","reinforcement","algorithm","probability","principle","sequential","investment","sensitive","behaviors","uncertain","correlation","transformations","difference","effectively","preferences","necessary","nonlinear","underlying","probabilities","interpretation","appropriate","subjective","responses","different","applicability","approximate","computation","measurement","differential","measurements","equations","continuity","computations","suggested","representation","intrinsic","technique","continuous","mathematical","uncertainty","drastically","derivatives","developed","processes","industrial","alternatives","concentrate","understanding","positions","conditions","modelling","simplicity","presented","traditional","historically","passengers","interested","searching","recurrent","difficulties","conditional","evaluated"],"y":[72,47,377,35,55,101,57,155,141,351,69,5,3,138,11,19,92,3,312,140,3,4,172,96,249,3,559,8,137,6,134,31,73,15,431,112,27,186,227,112,140,114,13,876,137,55,363,121,328,27,629,124,40,202,84,241,48,105,139,388,269,143,178,103,167,60,68,14,104,12,119,585,441,37,258,89,74,240,338,82,42,8,183,126,9,177,89,212,378,99,99,203,32,19,56,34,40,132,9,57,34,132,66,27,103,679,54,3,52,22,40,2,9,192,206,5,563,47,2,86,196,3,145,17,250,46,88,64,43,59,111,65,236,57,120,72,367,5,21,121,795,170,46,63,6,64,27,26,77,37,71,116,34,48,62,125,60,65,80,27,18,721,42,101,155,49,24,55,29,8,35,27,383,40,273,99,58,96,16,9,201,100,19,28,10,150,31,114,60,27,210,167,1,2,25,31,143,27,78,131],"type":"bar"},{"x":["estimates","minimizing","knowledge","inferring","realistic","recons ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4535,), (4535, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8133333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Accurate</span> <span style=''>Vision</span> <span style=''>based</span> <span style=''>Vehicle</span> <span style='background-color:rgba(0, 255, 0, 0.7971014492753623);'>Localization</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.5833333333333335);'>Satellite</span> <span style=''>Imagery</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accurately</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>localizing</span> <span style=''>ground</span> <span style=''>vehicles</span> <span style=''>with</span> <span style=''>the</span> <span style=''>aid</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.5833333333333335);'>satellite</span> <span style=''>imagery</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>takes</span> <span style=''>a</span> <span style=''>ground</span> <span style=''>image</span> <span style=''>as</span> <span style=''>input</span> <span style=''>and</span> <span style=''>outputs</span> <span style=''>the</span> <span style=''>location</span> <span style=''>from</span> <span style=''>which</span> <span style=''>it</span> <span style=''>was</span> <span style=''>taken</span> <span style=''>on</span> <span style=''>a</span> <span style=''>georeferenced</span> <span style='background-color:rgba(0, 255, 0, 0.5833333333333335);'>satellite</span> <span style=''>image</span> <span style=''>We</span> <span style=''>perform</span> <span style=''>visual</span> <span style='background-color:rgba(0, 255, 0, 0.7971014492753623);'>localization</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.44680851063829796);'>estimating</span> <span style=''>the</span> <span style=''>co</span> <span style='background-color:rgba(0, 255, 0, 0.3714285714285714);'>occurrence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>between</span> <span style=''>the</span> <span style=''>ground</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.5833333333333335);'>satellite</span> <span style=''>images</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>ground</span> <span style='background-color:rgba(0, 255, 0, 0.5833333333333335);'>satellite</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>The</span> <span style=''>method</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style=''>estimate</span> <span style='background-color:rgba(255, 0, 0, 0.30434782608695665);'>likelihoods</span> <span style=''>over</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>locations</span> <span style=''>without</span> <span style=''>the</span> <span style=''>need</span> <span style=''>for</span> <span style=''>a</span> <span style=''>dense</span> <span style=''>ground</span> <span style=''>image</span> <span style=''>database</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>ranking</span> <span style=''>loss</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>learns</span> <span style=''>location</span> <span style='background-color:rgba(0, 255, 0, 0.49999999999999994);'>discriminative</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projection</span> <span style=''>matrices</span> <span style=''>that</span> <span style=''>result</span> <span style=''>in</span> <span style=''>further</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>improvements</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Distance</span> <span style=''>weighted</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machine</span> <br/><br/><span style=''>A</span> <span style=''>novel</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>method</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>possesses</span> <span style=''>the</span> <span style=''>merits</span> <span style=''>of</span> <span style=''>both</span> <span style=''>the</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machine</span> <span style=''>(SVM)</span> <span style=''>and</span> <span style=''>the</span> <span style=''>Distance</span> <span style=''>weighted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discrimination</span> <span style=''>(DWD)</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>in</span> <span style=''>this</span> <span style=''>article</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>Distance</span> <span style=''>weighted</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machine</span> <span style=''>method</span> <span style=''>can</span> <span style=''>be</span> <span style=''>viewed</span> <span style=''>as</span> <span style=''>a</span> <span style=''>hybrid</span> <span style=''>of</span> <span style=''>SVM</span> <span style=''>and</span> <span style=''>DWD</span> <span style=''>that</span> <span style=''>finds</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>direction</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizing</span> <span style=''>mainly</span> <span style=''>the</span> <span style=''>DWD</span> <span style=''>loss</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determines</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intercept</span> <span style=''>term</span> <span style=''>in</span> <span style=''>the</span> <span style=''>SVM</span> <span style=''>manner</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style=''>method</span> <span style=''>inheres</span> <span style=''>the</span> <span style=''>merit</span> <span style=''>of</span> <span style=''>DWD</span> <span style=''>and</span> <span style=''>hence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overcomes</span> <span style=''>the</span> <span style=''>data</span> <span style=''>piling</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overfitting</span> <span style=''>issue</span> <span style=''>of</span> <span style=''>SVM</span> <span style=''>On</span> <span style=''>the</span> <span style=''>other</span> <span style=''>hand</span> <span style=''>the</span> <span style=''>new</span> <span style=''>method</span> <span style=''>is</span> <span style=''>not</span> <span style=''>subject</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imbalanced</span> <span style=''>data</span> <span style=''>issue</span> <span style=''>which</span> <span style=''>was</span> <span style=''>a</span> <span style=''>main</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style=''>SVM</span> <span style=''>over</span> <span style=''>DWD</span> <span style=''>It</span> <span style=''>uses</span> <span style=''>an</span> <span style=''>unusual</span> <span style=''>loss</span> <span style=''>which</span> <span style=''>combines</span> <span style=''>the</span> <span style=''>Hinge</span> <span style=''>loss</span> <span style=''>(of</span> <span style=''>SVM)</span> <span style=''>and</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Tracking</span> <span style=''>Slowly</span> <span style=''>Moving</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333334);'>Clairvoyant</span> <span style=''>Optimal</span> <span style=''>Dynamic</span> <span style=''>Regret</span> <span style=''>of</span> <span style=''>Online</span> <span style=''>Learning</span> <span style=''>with</span> <span style=''>True</span> <span style=''>and</span> <span style=''>Noisy</span> <span style=''>Gradient</span> <br/><br/><span style=''>This</span> <span style=''>work</span> <span style=''>focuses</span> <span style=''>on</span> <span style=''>dynamic</span> <span style=''>regret</span> <span style=''>of</span> <span style=''>online</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>that</span> <span style=''>compares</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>online</span> <span style=''>learning</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333334);'>clairvoyant</span> <span style=''>who</span> <span style=''>knows</span> <span style=''>the</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>in</span> <span style=''>advance</span> <span style=''>and</span> <span style=''>hence</span> <span style=''>selects</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333334);'>minimizer</span> <span style=''>of</span> <span style=''>the</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>at</span> <span style=''>each</span> <span style=''>step</span> <span style=''>By</span> <span style=''>assuming</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333334);'>clairvoyant</span> <span style=''>moves</span> <span style=''>slowly</span> <span style=''>(ie</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6923076923076923);'>minimizers</span> <span style=''>change</span> <span style=''>slowly)</span> <span style=''>we</span> <span style=''>present</span> <span style=''>several</span> <span style=''>improved</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variation</span> <span style=''>based</span> <span style=''>upper</span> <span style=''>bounds</span> <span style=''>of</span> <span style=''>the</span> <span style=''>dynamic</span> <span style=''>regret</span> <span style=''>under</span> <span style=''>the</span> <span style=''>true</span> <span style=''>and</span> <span style=''>noisy</span> <span style=''>gradient</span> <span style=''>feedback</span> <span style=''>which</span> <span style=''>are</span> <span style=''>it</span> <span style=''>optimal</span> <span style=''>in</span> <span style=''>light</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.37704918032786877);'>presented</span> <span style=''>lower</span> <span style=''>bounds</span> <span style=''>The</span> <span style=''>key</span> <span style=''>to</span> <span style=''>our</span> <span style=''>analysis</span> <span style=''>is</span> <span style=''>to</span> <span style=''>explore</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularity</span> <span style=''>metric</span> <span style=''>that</span> <span style=''>measures</span> <span style=''>the</span> <span style=''>temporal</span> <span style=''>changes</span> <span style=''>in</span> <span style=''>the</span> <span style=''>clairvoyants</span> <span style='background-color:rgba(255, 0, 0, 0.6923076923076923);'>minimizers</span> <span style=''>to</span> <span style=''>which</span> <span style=''>we</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Assisted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dictionary</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>fMRI</span> <span style=''>Data</span> <span style=''>Analysis</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Extracting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>magnetic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resonance</span> <span style=''>(fMRI)</span> <span style=''>images</span> <span style=''>has</span> <span style=''>been</span> <span style=''>a</span> <span style=''>major</span> <span style=''>area</span> <span style=''>of</span> <span style=''>research</span> <span style=''>for</span> <span style=''>more</span> <span style=''>than</span> <span style=''>two</span> <span style=''>decades</span> <span style=''>The</span> <span style=''>goal</span> <span style=''>of</span> <span style=''>this</span> <span style=''>work</span> <span style=''>is</span> <span style=''>to</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>for</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>fMRI</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>that</span> <span style=''>is</span> <span style=''>capable</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporate</span> <span style=''>a</span> <span style=''>priori</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>via</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>Tests</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style=''>data</span> <span style=''>sets</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>gains</span> <span style=''>over</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>of</span> <span style=''>this</span> <span style=''>kind</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08312786192321239)
# 	experimental (0.13349771046143008)
# 	representation (0.13490665727368792)
# 	information (0.23916872138076786)
# 	segmentation (0.07291299753434308)
# 	knowledge (0.13279323705530116)
# 	detection (0.11905600563578725)
# 	different (0.25396266290947517)
# 	convolutional (0.12363508277562522)
# 	recognition (0.12786192321239873)
#
# Some Statistics words are:
# 	stochastic (0.1315655277919429)
# 	theoretical (0.1509433962264151)
# 	variables (0.1438041815400306)
# 	statistical (0.16216216216216217)
# 	inference (0.18765935747067822)
# 	estimation (0.17797042325344212)
# 	distribution (0.18612952575216726)
# 	algorithm (0.4013258541560428)
# 	dimensional (0.19581845996940336)
# 	regression (0.18306986231514533)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="739a9b04-0383-4ec9-b25f-2ade8f336d02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("739a9b04-0383-4ec9-b25f-2ade8f336d02")) {                    Plotly.newPlot(                        "739a9b04-0383-4ec9-b25f-2ade8f336d02",                        [{"x":["estimates","minimizing","knowledge","inferring","realistic","reconstruction","motivated","extensive","resolution","convolutional","frequency","perceptually","principally","resulting","discriminator","perceptual","adversarial","unsatisfying","optimization","similarity","upscaling","breakthroughs","objective","benchmarks","significant","downsampled","framework","differentiate","generative","advancement","literature","activities","additionally","summarize","approaches","challenges","incremental","automatic","application","conventional","unsupervised","generalization","tremendous","performance","extraction","heuristic","recognition","promising","introduce","ambiguity","experiments","competitive","increased","functions","perspective","evaluation","established","improvements","practical","efficient","significantly","comparison","benchmark","typically","theoretical","interesting","comparing","modifications","simultaneously","multiclass","development","algorithms","applications","representative","challenging","sequences","annotated","including","detection","scenarios","transition","concurrent","dimensional","distributions","advantageous","selection","illustrate","distribution","important","consistent","embedding","properties","estimator","similarly","invariant","dependence","contributions","variables","discrepancy","statistics","independence","convergence","transformation","measuring","increasing","information","dependency","distractors","estimating","monocular","predicted","distraction","cluttered","estimation","automatically","photometric","demonstrate","independently","distractor","environments","supervised","egomotion","implementation","localized","outperforms","evaluations","predictions","explicitly","attribute","partially","especially","attributes","architecture","decisions","combining","determine","techniques","committee","behavioral","reinforcement","algorithm","probability","principle","sequential","investment","sensitive","behaviors","uncertain","correlation","transformations","difference","effectively","preferences","necessary","nonlinear","underlying","probabilities","interpretation","appropriate","subjective","responses","different","applicability","approximate","computation","measurement","differential","measurements","equations","continuity","computations","suggested","representation","intrinsic","technique","continuous","mathematical","uncertainty","drastically","derivatives","developed","processes","industrial","alternatives","concentrate","understanding","positions","conditions","modelling","simplicity","presented","traditional","historically","passengers","interested","searching","recurrent","difficulties","conditional","evaluated","shortcomings","particular","mechanism","itinerary","assumptions","alternative","providers","attention","therefore","classical","statistical","filtering","prediction","correspond","passenger","multinomial","experimental","classification","classifier","nevertheless","classifies","regression","formulation","computationally","implication","transport","generating","marginals","semidefinite","withdrawn","currently","allocation","meaningful","interpretable","structure","relatively","communities","assortativity","interaction","demonstrated","components","introduced","nonparametric","dirichlet","community","structures","seriously","component","functional","competitors","effective","computing","linguistic","artificial","addressed","fundamental","represe ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	itinerary
# 	assortativity
# 	procrustes
# 	emphstatistical
# 	covariates
# 	spherically
# 	collapsed
# 	complicate
# 	strikingly
# 	reparametrization
# 	beginnings
# 	statistician
# 	stationarities
# 	integrality
# 	subgroups
# 	exchanges
# 	asynchronously
# 	semiparametric
# 	nonparanormal
# 	divergences
# Some words which never appear in Statistics papers:
# 	perceptually
# 	downsampled
# 	differentiate
# 	monocular
# 	distraction
# 	photometric
# 	egomotion
# 	committee
# 	withdrawn
# 	rudimentary
# 	imprecision
# 	abstractions
# 	benchmarked
# 	possibilistic
# 	grammatically
# 	diffusing
# 	broadcast
# 	primitive
# 	mammograms
# 	mammogram

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0372057706909645e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7508333333333334
